# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
monalisa = np.load('monalisa.npy')

# %%
monalisa.shape
# Out:
# (1198, 804, 3)

# %%
pp.imshow(monalisa)
